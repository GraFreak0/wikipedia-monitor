# %% [markdown]
# # Import all necessary Libraries and Module
# ## Extract Dump file

# %%
import glob
import numpy as np
import pandas as pd

# %%
# df1 = pd.read_csv('../dumps/wikipedia_pageviews_20251023_10.csv')
# df2 = pd.read_csv('../dumps/wikipedia_pageviews_20251023_11.csv')
# df3 = pd.read_csv('../dumps/wikipedia_pageviews_20251023_16.csv')
# df = pd.concat([df1, df2, df3], ignore_index=True)

csv_files = glob.glob('../dumps/*.csv')

# Combine all CSVs into one DataFrame
df = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True)
display(df.sort_values(by='page_views', ascending=False))
# Out:
#          domain_code                                         page_title  \
# 17993631          en                                          Main_Page
# 9833523           en                                          Main_Page
# 1825293           en                                          Main_Page
# 10075019          en                                     Special:Search
# 2061502           en                                     Special:Search
# ...              ...                                                ...
# 22               NaN  File:Il_Friuli_giornale_politico-amministrativ...
# 21               NaN  File:Il_Cittadino_Italiano_n_280-1888_(IA_Citt...
# 20               NaN  File:IP_services_design_and_implementation_in_...
# 19               NaN  File:History_of_the_Ninth_Mass._Battery._Recru...
# 4                NaN  File:A_visit_to_India,_China,_and_Japan._In_th...
#
#           page_views  bytes                       date
# ...
